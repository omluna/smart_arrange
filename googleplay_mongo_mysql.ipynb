# %%
import requests
from bs4 import BeautifulSoup
import time
import pymongo
import pprint
import math
import pandas as pd
import numpy as np
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %%
client = pymongo.MongoClient('18.8.8.209')
cydb = client.cy
topapps = pd.DataFrame(list(cydb.top540.find()))
del topapps['_id']

# %%
cato = pd.read_csv('category.csv')

# %%
cydb.cy_cato.insert_many(cato.to_dict(orient='record'))

# %%
import datetime

# %%
now = (datetime.date.today() - datetime.timedelta(days=1)).isoformat()

# %%
now
# Out:
# '2018-06-04'

# %%
cc = pd.DataFrame(list(cydb.googleplay_country.find(projection={'_id': False, 'country_name': False})))

list(cc['country_code'])

# %%
list(cydb.topapp_cat.find(projection={'_id': False, 'id': False}))
# Out:
# [{'abbr': 'TOOLS',
#   'category': 'PRODUCTIVITY',
#   'title': 'Tools',
#   'title_chs': '工具'},
#  {'abbr': 'TOOLS',
#   'category': 'PERSONALIZATION',
#   'title': 'Tools',
#   'title_chs': '工具'},
#  {'abbr': 'TOOLS', 'category': 'TOOLS', 'title': 'Tools', 'title_chs': '工具'},
#  {'abbr': 'TOOLS',
#   'category': 'PARENTING',
#   'title': 'Tools',
#   'title_chs': '工具'},
#  {'abbr': 'TOOLS', 'category': 'EVENTS', 'title': 'Tools', 'title_chs': '工具'},
#  {'abbr': 'TOOLS', 'category': 'WEATHER', 'title': 'Tools', 'title_chs': '工具'},
#  {'abbr': 'GAMES',
#   'category': 'GAME_ACTION',
#   'title': 'Games',
#   'title_chs': '游戏'},
#  {'abbr': 'GAMES',
#   'category': 'GAME_ADVENTURE',
#   'title': 'Games',
#   'title_chs': '游戏'},
#  {'abbr': 'GAMES',
#   'category': 'GAME_ARCADE',
#   'title': 'Games',
#   'title_chs': '游戏'},
#  {'abbr': 'GAMES',
#   'category': 'GAME_BOARD',
#   'title': 'Games',
#   'title_chs': '游戏'},
#  {'abbr': 'GAMES',
#   'category': 'GAME_CASINO',
# ...

# %%
df = pd.DataFrame(list(cydb.topapp_cat.find(projection={'_id': False, 'id': False})))

# %%
cc = df[df['category'] == 'PRODUCTIVITYt']['abbr'].values[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-198-70be1fcb6aff> in <module>()
# ----> 1 cc = df[df['category'] == 'PRODUCTIVITYt']['abbr'].values[0]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
cc
# Out:
# 'TOOLS'

# %%
top = pd.read_csv('topapp_tr.csv')

# %%
#cydb.topapp_cat.insert_many(cato.to_dict(orient='record'))   已经存到 mongodb 了，不需要重新做
#cydb.topapps.insert_many(topapps.to_dict(orient='record'))

topapps['category_id'] = topapps['category'].apply(lambda x:cato[cato['category'] == x]['id'].iloc[0])
topapps.loc[640, 'name'] = 'CM Launcher 3D Pro'
topapps.iloc[640]['name']
topapps['package_name'] = topapps['href'].apply(lambda x:x.split('=')[-1])

# %%
topapps['pos'][540]
# Out:
# 2

# %%
conn = create_engine('mysql+pymysql://websrv:websrv#2017@127.0.0.1/cy_websrv?charset=utf8')

# %% [markdown]
# ### TO MYSQL

# %%
conn = create_engine('postgresql+psycopg2://root:Changeme@18.8.8.208:3306/cy_websrv?charset=utf8')  
pd.io.sql.to_sql(cato,'topapp_cato',con=conn,if_exists='replace')
pd.io.sql.to_sql(topapps,'topapps',con=conn,if_exists='replace')

# %%
topselling = topapps[topapps.type == 1]
topfree = topapps[topapps.type == 0]

# %%
topselling.set_index('pos')[['name', 'package_name', 'category']].to_csv('topselling')

# %%
topfree.set_index('pos')[['name', 'package_name', 'category']].to_csv('topfree')

# %%
import requests

url = "https://play.google.com/store/apps/collection/topselling_free"

querystring = {"authuser":"0","start":180,"num":119,"numChildren":"0","cctcss":"square-cover","cllayout":"NORMAL","ipf":"1","xhr":"1"}

headers = {
    'accept': "*/*",
    'accept-encoding': "gzip, deflate, br",
    'accept-language': "en;",
    'cookie': "HSID=AG82OPMBeuNmdVcpg; SSID=AlqY-W6cRxtxlGig5; APISID=2Cll8EW--jaFAmUu/AsKJC_t9XbEQRfBvd; SAPISID=4eJc6hPRSxRrqBr6/AfeoBHGWoMOZZs2tE; SID=3AWVKgajPAb3-nflI6GmAzYykB7aAP2tsImb-hUfnWNjwbQ6_Sxz5ERlV76Kp1oYdbsFnw.; PLAY_ACTIVE_ACCOUNT=ICrt_XL61NBE_S0rhk8RpG0k65e0XwQVdDlvB6kxiQ8=amit.luu@gmail.com; _ga=GA1.3.1314769735.1523435478; OTZ=4352192_24_24__24_; SIDCC=AEfoLebf52D4nndXoovcdyTN-SfxtIhdxEsC1Mb6oCkFDvAP_AzD_G1w1TFctH0oZ89FeUxHyg; NID=128=fOd4E_zJKKPMDx2Y9K5l64SkyeuxtEAdFoSXI9KtxJKYVGykt5xW4xxyujI6A5Nh3DG0dKGTt921GT95RLZY936K_spX5wZD4wYWQl37qkK-lwDnS1FgO4vNgL43a1AUGCsHlrJXFdF6V8s2HFOeq6l3MIepKKdYAcspBlYUGAVqjZTOX8grJLYc7htJBcV3Peu7lPwmXy28KYdCa3yp5jXZ0OEcd36dFJmOBKc0MORtjbkcPeNueEGfc23_REl659BiZ7Rg1ZRSNQ7rz6ov3UpbOSX7; 1P_JAR=2018-4-24-1; _gid=GA1.3.138382773.1524533993; _gat_UA199959031=1; PLAY_PREFS=CqIMCJXVxOfqGBKYDAoCVFcQnMKwkq0sGtkLEhMUFRjxAasC4QPCBOMF5QXoBdcGkJWBBpGVgQaSlYEGlZWBBpeVgQaklYEGuJWBBsCVgQbBlYEGxJWBBsWVgQbIlYEGyZWBBs6VgQbPlYEG0JWBBtSVgQbYlYEG3pWBBvGVgQb4lYEG-pWBBoaWgQaIloEGjJaBBo-WgQaSloEGnpaBBp-WgQahloEGpJaBBqaWgQanloEG7peBBu-XgQaBmIEGhZiBBomYgQa-mIEGq5uBBq2bgQbIm4EGypuBBsubgQbVm4EGvJ2BBt2dgQbnnYEGkJ6BBuKigQbzooEGi6OBBpqkgQaypIEG6qWBBsamgQbPp4EGvKyBBtavgQaHsoEGibKBBtaygQbJs4EGsbSBBta5gQaOwIEGosCBBsDAgQbBwIEG8sCBBtbCgQaMxYEG-MeBBqrKgQbYzIEG
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36",
    }

response = requests.request("POST", url, headers=headers, params=querystring)

print(response.status_code)
# Out:
# 200

# %%
app_list = []
for start in range(0,290,99):
    querystring['start'] = start
    print(querystring)
    response = requests.request("POST", url, headers=headers, params=querystring)
    print(response.status_code)
    time.sleep(10)
    soup = BeautifulSoup(response.text, "lxml")

    hrefs = soup.find_all('a')
    for href in hrefs:
        try:
            if 'title' in href['class']:
                app_list.append({'name': href['title'], 'href': href['href']})
        except:
            pass

print(len(app_list))
# Out:
# {'authuser': '0', 'start': 0, 'num': 99, 'numChildren': '0', 'cctcss': 'square-cover', 'cllayout': 'NORMAL', 'ipf': '1', 'xhr': '1'}
# 200
# {'authuser': '0', 'start': 99, 'num': 99, 'numChildren': '0', 'cctcss': 'square-cover', 'cllayout': 'NORMAL', 'ipf': '1', 'xhr': '1'}
# 200
# {'authuser': '0', 'start': 198, 'num': 99, 'numChildren': '0', 'cctcss': 'square-cover', 'cllayout': 'NORMAL', 'ipf': '1', 'xhr': '1'}
# 200
# 297

# %%
app_list[0]
# Out:
# {'href': '/store/apps/details?id=com.h8games.helixjump', 'name': 'Helix Jump'}

# %%
import requests

url = "https://play.google.com//store/apps/details?id=com.google.android.apps.paidtasks"

#querystring = {"id":"com.area120.grasshopper"}

headers = {
    'accept': "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    'cookie':"_ga=GA1.3.1314769735.1523435478; SID=DAaVKqDYVfUDOvDttkKw4L9_fFoj3k4amZyPFCJv2-JrhZoD2gLvVPLqDS9ipsTYjwXWmw.; HSID=Az021_6ePZogKY8cM; SSID=ACpzbNvy8_x8Vnybk; APISID=7S1tb3ZsgGv_bYvR/ACjOTyZPnt4umXRCq; SAPISID=xjIFc_YmAa63ey27/AmEbiR4E6aujvkXPS; PLAY_ACTIVE_ACCOUNT=ICrt_XL61NBE_S0rhk8RpG0k65e0XwQVdDlvB6kxiQ8=amit.luu@gmail.com; OGPC=19005936-1:; OTZ=4405361_24_24__24_; _gid=GA1.3.2048843400.1526865050; S=billing-ui-v3=eWeD_wxbzs3JRADxJ-CL6W5mS67k_4No:billing-ui-v3-efe=eWeD_wxbzs3JRADxJ-CL6W5mS67k_4No; 1P_JAR=2018-5-21-10; NID=130=Be1qWHB3o0rDQHglTTz2_NVkMWFbMRxRsfuHCKi_dDX1-tdEiGz6EnriBD6hIM5bF7KDCiLVQ5tp1QUgXwKCXWeBSpWysL7s_j_3V_G5uu8uF6D8J8nfAvzHr2C2pmBiprSMQY399cBMmgnAH0s0McaYmi3vn0Au_7NtPRUGfdWonzvzif_6MtkBZjxvQrFLFOJncOFOrFElPGABMpUVYFGIhGbMebvscYBvB8W2-RtryaoaZKh6zvElYn-lKaYU8DJ9PgNomxLgEvBzhutCLlul; PLAY_PREFS=...-BBsTSgQaV1YEG2tiBBpPZgQby24EGzeSBBtjkgQa46IEGz-uBBrDs
Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/65.0.3325.181 Safari/537.36",
    }

response = requests.request("GET", url, headers=headers)

soup_app = BeautifulSoup(response.text)
# Out:
# /anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
href_all = soup_app.find_all('a')

# %%
for href in href_all:
    try:
        if 'genre' == href['itemprop']:
            print(href['href'])
            break
    except:
        pass
# Out:
# https://play.google.com/store/apps/category/TOOLS

# %%
soup = BeautifulSoup(open('tr_app_top.htm', encoding='utf-8'), "lxml")

# %%
app_lists = soup.find_all(class_='app-link-container')

# %%
app_lists
# Out:
# [<div class="app-link-container">
#  <a class="app-link" data-other-android="false" href="https://www.appannie.com/apps/google-play/app/com.zhiliaoapp.musically/details/" id="20600004552886">
#  <span title="musical.ly">musical.ly</span>
#  </a>
#  </div>, <div class="app-link-container">
#  <a class="app-link" data-other-android="false" href="https://www.appannie.com/apps/google-play/app/com.eightsec.TimeCrashAndroid/details/" id="20600008064917">
#  <span title="Time Crash - Full">Time Crash - Full</span>
#  </a>
#  </div>, <div class="app-link-container">
#  <a class="app-link" data-other-android="false" href="https://www.appannie.com/apps/google-play/app/com.azarlive.android/details/" id="20600001666449">
#  <span title="Azar">Azar</span>
#  </a>
#  </div>, <div class="app-link-container">
#  <a class="app-link" data-other-android="false" href="https://www.appannie.com/apps/google-play/app/com.genetic.realcarparking2/details/" id="20600009603009">
# ...

# %%
app_lists[220]
# Out:
# <div class="app-link-container">
# <a class="app-link" data-other-android="false" href="https://www.appannie.com/apps/google-play/app/com.sbkgames.RacingLimits/details/" id="20600009551179">
# <span title="Racing Limits">Racing Limits</span>
# </a>
# </div>

# %%
for i, app in enumerate(app_lists):
    print("{} {}".format(i, app.a['href'].split('/')[-3]))
# Out:
# 0 com.zhiliaoapp.musically
# 1 com.eightsec.TimeCrashAndroid
# 2 com.azarlive.android
# 3 com.genetic.realcarparking2
# 4 jaredjohnson.iamrichcalculator
# 5 com.h8games.helixjump
# 6 com.BenimHocam.KPSSSenBilirsin
# 7 net.peakgames.Yuzbir
# 8 com.crazylabs.lady.bug
# 9 aliceteam.theme.twilight.night.black
# 10 com.kwai.video
# 11 com.ubisoft.assassinscreed.identity
# 12 com.longtech.lastwars.gp
# 13 com.launcher.theme3d.t600001399
# 14 com.xda.nobar.premium
# 15 com.whatsapp
# 16 com.fazilettakvimi.fazilettakvimi
# 17 com.igg.android.lordsmobile
# 18 io.voodoo.cube
# 19 com.BenimHocam.KPSSSenBilirsin
# 20 com.instagram.android
# 21 com.notdoppler.earntodie
# 22 com.hcg.cok.gp
# 23 com.dimchi.crush
# 24 com.DoubleMoose.AnimalSuperSquad
# 25 com.facebook.orca
# 26 com.realdrift.sipon
# 27 com.zynga.livepoker
# 28 com.playgendary.flipgun
# 29 com.noodlecake.gettingoverit
# 30 com.supertapx.lovedots
# 31 com.nekki.shadowfight2.paid
# 32 com.tinder
# 33 com.WR.snake2
# ...

# %%
app_info_list = []
pos = 0

# %%
for i, app in enumerate(app_lists):
    if i%5 in [0, 1]:
        pos += 1
        if app.a['href'].split('/')[-3] != '':
            app_info_list.append({'package_name':app.a['href'].split('/')[-3], 'name':app.span.string, 'pos':pos})

# %%
len(app_info_list)
# Out:
# 598

# %%
base_url = 'https://play.google.com//store/apps/details?id='

# %%
headers = {
    'accept': "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
    'accept-encoding': "gzip, deflate, br",
    'accept-language': "zh-CN,zh;q=0.9,en;q=0.8,zh-TW;q=0.7",
    'cache-control': "no-cache",
    'cookie': "_ga=GA1.3.1314769735.1523435478; SID=DAaVKqDYVfUDOvDttkKw4L9_fFoj3k4amZyPFCJv2-JrhZoD2gLvVPLqDS9ipsTYjwXWmw.; HSID=Az021_6ePZogKY8cM; SSID=ACpzbNvy8_x8Vnybk; APISID=7S1tb3ZsgGv_bYvR/ACjOTyZPnt4umXRCq; SAPISID=xjIFc_YmAa63ey27/AmEbiR4E6aujvkXPS; PLAY_ACTIVE_ACCOUNT=ICrt_XL61NBE_S0rhk8RpG0k65e0XwQVdDlvB6kxiQ8=amit.luu@gmail.com; OGPC=19005936-1:; OTZ=4405361_24_24__24_; _gid=GA1.3.2048843400.1526865050; S=billing-ui-v3=eWeD_wxbzs3JRADxJ-CL6W5mS67k_4No:billing-ui-v3-efe=eWeD_wxbzs3JRADxJ-CL6W5mS67k_4No; 1P_JAR=2018-5-21-10; NID=130=Be1qWHB3o0rDQHglTTz2_NVkMWFbMRxRsfuHCKi_dDX1-tdEiGz6EnriBD6hIM5bF7KDCiLVQ5tp1QUgXwKCXWeBSpWysL7s_j_3V_G5uu8uF6D8J8nfAvzHr2C2pmBiprSMQY399cBMmgnAH0s0McaYmi3vn0Au_7NtPRUGfdWonzvzif_6MtkBZjxvQrFLFOJncOFOrFElPGABMpUVYFGIhGbMebvscYBvB8W2-RtryaoaZKh6zvElYn-lKaYU8DJ9PgNomxLgEvBzhutCLlul; PLAY_PREFS=...-BBsTSgQaV1YEG2tiBBpPZgQby24EGzeSBBtjkgQa46IEGz-uBBrDsgQbX9YEGuvuBBr__gQbF_4EGx_-BBsj_gQbVg4IGyISCBrmGggamh4IGp4eCBuyHggbth4IG-42CBomOggbMkYIGlZiCBo-aggaZmoIGwZqCBveaggadnoIG1Z6CBrqggga7oIIG9qKCBpKlggarpYIGzaWCBvKnggaeqIIGtKiCBq22ggb8uYIG_rmCBv-5ggbCu4IGj7-CBurAgga8wYIGkMuCBpHLggbNy4IG0cuCBtzMggbY0IIG89GCBovSggbb04IGgdiCBoXaggaP2oIGmtqCBqPaggau24IGvtuCBsXbggax3IIG-N2CBu_fggam4YIGlumCBqPtggaF7oIGmu6CBrPuggaM8IIGsfCCBpbxgga-8YIG6_aCBq34ggaz-IIG9vqCBt_7ggbj-4IGg_yCBoX8ggbb_IIG3PyCBv_8ggaB_YIGgv-CBoCAgwaJgYMG8oGDBumEgwaQhYMGuoWDBteFgwabiIMGuYiDBvCIgwaFj4MGkI-DBtmRgwb8kYMG_JKDBqyVgwa4lYMGwJaDBuSWgwbcl4MG8ZmDBvSZgwaZm4MG7ZuDBu6bgwbQnIMG8Z6DBvSegwaVn4MGxp-DBtOfgwaYoIMGm6CDBv2ggwa5o4MG4K6DBuyvgwaWsIMGlbSDBpi0gwa4toMGpLeDBq-4gwa5uIMGw7iDBuC8gwb0vIMG9ryDBqy-gwbNvoMG8sGDBsbCgwbJwoMG5MaDBq3IgwaeyYMGm8qDBofNgwbKzYMG_s2DBqLQgwbo0IMGwNODBvnTgwbr1IMGh9WDBs_Wgwbr1oMG49eDBunXgwbR2YMGrNyDBo7dgwbh34MGhuCDBojggwaa4YMG7-ODBv_lgwam7IMG6uyDBo7tgwaV7oMG4--DBpzygwb79IMGrveDBq_3gwbw94MG-feDBoz4gwaN-IMG1vmDBt75gwac-oMGsfqDBsL6gwak_oMGh_-DBpGAhAaSgIQGo4CEBtWBhAbdgYQG34GEBvqDhAaPhIQG14SEBpaHhAbih4QG44eEBsmIhAbKiIQGpImEBr6JhAb7ioQGp4uEBpqMhAbzjIQGgI6EBoeOhAasjoQGm4-EBoaQhAbckoQG75OEBsiXhAaKmIQG85iEBoaZhAabmYQGopmEBv2ahAacnIQG4JyEBoqdhAbbnYQGs56EBvOehAbgn4QG16GEBs2jhAbwo4QGi6SEBrGkhAatpYQG_6eEBqmohAaSqYQGoKmEBqaphAaoqYQGrKmEBtKphAbTqYQGna-EBqevhAbBr4QG96-EBvivhAapsIQGgLOEBre0hAaltYQGkraEBqG2hAb1toQG-reEBte4hAbyuIQGhbmEBqq5hAbAuYQGyruEBs67hAbiu4QG5buEBva7hAanvYQGs72EBsy9hAbQvYQG0r2EBtW9hAbXvYQG2r2EBt69hAbEvoQGkr-EBqy_hAbMv4QG47-EBoDAhAajwIQGxcCEBpjBhAajwYQGvsGEBoPDhAaNw4QGk8SEBpjEhAbTxIQG0cWEBuLFhAYosceErLgsOiRjMDVjY2I5MC0wYjFhLTQ0MmMtOWY4NS1hNDhhMzA1NDFiMGJAAUgA:S:ANO1ljLPyVHY6Q6-sA; SIDCC=AEfoLeZSyBHcQZ_1doEdhhko8gdUea7THltLB-OzipuIBdBliQgS-aXVP3aeclfvNyUk86SnyA",
    'upgrade-insecure-requests': "1",
    'user-agent': "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.181 Safari/537.36",
    }

# %%
for app in app_info_list:
    detail_url = base_url + app['package_name']
    print(detail_url)
    response = requests.request("GET", detail_url, headers=headers)
    
    if response.status_code != 200:
        print('got {} failed'.format(app['name']))
    else:
        soup = BeautifulSoup(response.text, "lxml")
        hrefs = soup.find_all('a')
        for href in hrefs:
            try:
                if 'genre' == href['itemprop']:
                    app['category'] = href['href'].split('/')[-1]
                    #app['type'] = 1
                    #print(app['category'])
                    break
            except:
                pass
    #time.sleep(1)
# Out:
# https://play.google.com//store/apps/details?id=com.zhiliaoapp.musically
# https://play.google.com//store/apps/details?id=com.eightsec.TimeCrashAndroid
# https://play.google.com//store/apps/details?id=com.h8games.helixjump
# https://play.google.com//store/apps/details?id=com.BenimHocam.KPSSSenBilirsin
# https://play.google.com//store/apps/details?id=com.kwai.video
# https://play.google.com//store/apps/details?id=com.ubisoft.assassinscreed.identity
# https://play.google.com//store/apps/details?id=com.whatsapp
# https://play.google.com//store/apps/details?id=com.fazilettakvimi.fazilettakvimi
# https://play.google.com//store/apps/details?id=com.instagram.android
# https://play.google.com//store/apps/details?id=com.notdoppler.earntodie
# https://play.google.com//store/apps/details?id=com.facebook.orca
# https://play.google.com//store/apps/details?id=com.realdrift.sipon
# https://play.google.com//store/apps/details?id=com.supertapx.lovedots
# ...

# %%
for app in app_info_list:
    if 'category' not in app:
        detail_url = base_url + app['package_name']
        print(detail_url)
        response = requests.request("GET", detail_url, headers=headers)

        if response.status_code != 200:
            print('got {} failed'.format(app['name']))
        else:
            soup = BeautifulSoup(response.text, "lxml")
            hrefs = soup.find_all('a')
            for href in hrefs:
                try:
                    if 'genre' == href['itemprop']:
                        app['category'] = href['href'].split('/')[-1]
                        #app['type'] = 1
                        #print(app['category'])
                        break
                except:
                    pass
# Out:
# https://play.google.com//store/apps/details?id=com.paleblue.newbricks2
# got Bricks breaker king failed

# %%
for app in app_info_list:
    app['country'] = 'tr'
    app['last_update'] = time.time()

# %%
df = pd.DataFrame(app_info_list)

# %%
del df['_id']

# %%
df = df.fillna('0')

# %%
df.drop(253, inplace=True)

# %%
for cat in df['category']:
    if cat not in list(cato['category']):
        print(cat)
# Out:
# ART_AND_DESIGN

# %%
df['category_id'] = df['category'].apply(lambda x:cato[cato['category'] == x]['id'].iloc[0])

# %%
df.to_csv('topapp_tr.csv',index=False)

# %%
client = pymongo.MongoClient('18.8.8.209')
cydb = client.cy

# %%
cydb.topapp_tr.insert_many(app_info_list)

# %%
t = cydb.topapp_tr.find_one({'package_name':'com.h8games.helixjump'})

# %%
t['category']
# Out:
# 'GAME_ACTION'

# %%
import requests

url = "https://www.appannie.com/ajax/top-chart/table/"

querystring = {"market":"google-play","country_code":"EG","category":"1","date":"2018-05-21","rank_sorting_type":"rank","page_size":"300","order_type":"desc"}

headers = {
    'accept': "application/json, text/plain, */*",
    'accept-encoding': "gzip, deflate, br",
    'accept-language': "zh-CN,zh;q=0.9,en;q=0.8,zh-TW;q=0.7",
    'cookie': "optimizelyEndUserId=oeu1528194190178r0.8089536040737322; _ga=GA1.2.778478037.1528194191; _gid=GA1.2.226148796.1528194191; _mkto_trk=id:071-QED-284&token:_mch-appannie.com-1528194190588-56981; _tdim=a9e43662-9751-4b9b-f32e-28f40fd414f6; csrftoken=RQ3Yxttqwsehh3x7i17NDvR3MTgc2d9S; _hp2_ses_props.3646280627=%7B%22r%22%3A%22https%3A%2F%2Fwww.appannie.com%2Faccount%2Fregister%2F%3F_ref%3Dheader%22%2C%22ts%22%3A1528201539717%2C%22d%22%3A%22www.appannie.com%22%2C%22h%22%3A%22%2Faccount%2Fverify-email%2F%22%7D; welcome_carousel=1; rid=9028d36de21a4733ab7ebc895e42ec4b; _hp2_props.3646280627=%7B%22Logged%20In%22%3A%22true%22%2C%22aa_user_id%22%3A1400839%2C%22Email%22%3A%22luusuu%40126.com%22%2C%22AA%20User%20Type%20Long%22%3A%22%22%2C%22AA%20User%20is%20Verified%22%3A%22true%22%2C%22AA%20User%20Preferred%20Language%22%3A%22zh-cn%22%2C%22AA%20User%20is%20Intelligence%22%3A%22false%22%2C%22AA%20User%20is%20Store%20Intelligence%22%3A%22false%22%2C%22AA%20User%20is%20Usage%20Intelligence%22%3A%22false%22%2C%22AA%20User%20is%20Audience%20Intelligence%22%3A%22false%22%2C%22AA%20User%20is%20Marketing%20Intelligence%22%3A%22false%22%2C%22AA%20User%20is%20Intelligence%20API%22%3A%22false%22%2C%22AA%20User%20is%20Newsletter%20Subscriber%22%3A%22true%22%2C%22AA%20User%20is%20Blog%20Subscriber%22%3A%22false%22%7D; aa_user_token=\".eJxNzD0LAiEYAOC6imhoCdobmw7PNHKtqaDR2d57fUHp8DC1jyHop7c09AOe51O943CtZwXz0zhILlZ6pQC2DeMgJAMSILmSjKOUgjPLd2qjFwZKdqYkupkW8ErBxpFmD2ohQPfKHlMNiH0JuT5AomNIFJLP_k7n3lK3_5mxnv9N3sbJaXpZDkr9BWLCMlA:1fQB3l:KhNcfjcHqC3MdSeiXlBh0-dF9ow\"; aa_language=en; sessionId=\".eJxNzLtqAkEUgOF14yWs8ULAwt5Cm8Vn0CqRNJIBq0zOzhx0cDzreM4oCoKVkNf0SYIQJN3X_P8lPYfKULU0RFnpyLjTzr43vnuJevZAywhLXKRJkiCFVHUYmV1JGgkKj3aWqqaUrOPWgqD9Ua__PgWYNZJV4wMWQOCP4gznYEwZSfIpML4RI7ETt8eP0qKf_BVd8LgTbVZo1lrcBs19f0f2QHhSWeNWr730B-3Bl9ke5ZRp9TnNQnU0D7XrPNRj_guhU0yD:1fQB48:nUGNmXTPUo-cc6RBqTZinOtBXek\"; django_language=en; aa-cookie-done=1; wcs_bt=s_14249a956b4d:1528201845; _hp2_id.3646280627=%7B%22userId%22%3A%228111173746324231%22%2C%22pageviewId%22%3A%222061653134642730%22%2C%22sessionId%22%3A%225275403080355129%22%2C%22identity%22%3A%221400839%22%2C%22trackerVersion%22%3A%224.0%22%2C%22identityField%22%3Anull%2C%22isIdentified%22%3A1%7D",
    'referer': "https://www.appannie.com/apps/google-play/top-chart/?country=AR&category=1&device=&date=2018-06-05&feed=Free&rank_sorting_type=rank&page_number=0&page_size=300&table_selections=&order_type=desc&order_by=free_rank",
    'user-agent': "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/67.0.3396.62 Safari/537.36",
    'x-csrftoken': "RQ3Yxttqwsehh3x7i17NDvR3MTgc2d9S",
    'x-newrelic-id': "VwcPUFJXGwEBUlJSDgc=",
    'x-requested-with': "XMLHttpRequest",
    'cache-control': "no-cache",
    }


response = requests.request("GET", url, headers=headers, params=querystring)

# %%
response.json()
# Out:
# {'available': True,
#  'csvPermissionCode': 'PERMISSION_NOT_PASS',
#  'filter_settings': {'feed_type': {'context': [{'id': 'All', 'label': 'All'},
#     {'id': 'Free', 'label': 'Free'},
#     {'id': 'Paid', 'label': 'Paid'},
#     {'id': 'Grossing', 'label': 'Grossing'},
#     {'id': 'New-Free', 'label': 'New Free'},
#     {'id': 'New-Paid', 'label': 'New Paid'}],
#    'defaults': 'All'}},
#  'meta': {'exceed_date_limit': False},
#  'metrics': {'all': [],
#   'available_metrics': [],
#   'metrics_column_title_map': {},
#   'selected': []},
#  'reportCaption': {'reportDate': {'city_label': '',
#    'date_label': 'May 21, 2018',
#    'hour_label': '11:00pm',
#    'utc_offset_label': 'UTC+2'},
#   'userPreferTimezoneDate': {'city_label': 'Pacific Time, Los Angeles, Tijuana',
#    'date_label': 'May 21, 2018',
#    'hour_label': '2:00pm',
#    'utc_offset_label': 'UTC-7'}},
#  'table': {'columns': [[['#', '', [None]],
#     'sort_number',
#     'sort_order',
#     [False,
# ...

# %%
response.json()['table']['rows'][0][1:3][0][0]['url'].split('/')[-3]
# Out:
# 'com.facebook.orca'

# %%
def get_google_play_countries():
    headers = {'Authorization': 'Bearer d05683c381a2db185f7340022d06efbd1f9911a6'}
    url = 'https://api.appannie.com/v1.2/meta/countries' 
    response = requests.request("GET", url, headers=headers)
    
    if response.status_code != 200:
        print('aaa')
        return None
    df = pd.DataFrame(response.json()['country_list'])
    soup = BeautifulSoup(open('country.html', encoding='utf-8'), "lxml")
    countries = soup.find_all('span', attrs={'once-text':'c.label'})
    country_names = [x.string for x in countries]
    google_play_countries = df[df.country_name.isin(country_names)]
    
    return google_play_countries

# %%
google_play_country = get_google_play_countries()

# %%
google_play_country.to_dict(orient='record')
# Out:
# [{'country_code': 'AE', 'country_name': 'United Arab Emirates'},
#  {'country_code': 'AM', 'country_name': 'Armenia'},
#  {'country_code': 'AR', 'country_name': 'Argentina'},
#  {'country_code': 'AT', 'country_name': 'Austria'},
#  {'country_code': 'AU', 'country_name': 'Australia'},
#  {'country_code': 'AZ', 'country_name': 'Azerbaijan'},
#  {'country_code': 'BA', 'country_name': 'Bosnia and Herzegovina'},
#  {'country_code': 'BD', 'country_name': 'Bangladesh'},
#  {'country_code': 'BE', 'country_name': 'Belgium'},
#  {'country_code': 'BG', 'country_name': 'Bulgaria'},
#  {'country_code': 'BH', 'country_name': 'Bahrain'},
#  {'country_code': 'BO', 'country_name': 'Bolivia'},
#  {'country_code': 'BR', 'country_name': 'Brazil'},
#  {'country_code': 'BY', 'country_name': 'Belarus'},
#  {'country_code': 'CA', 'country_name': 'Canada'},
#  {'country_code': 'CH', 'country_name': 'Switzerland'},
#  {'country_code': 'CL', 'country_name': 'Chile'},
# ...

# %%
cydb.googleplay_country.insert_many(google_play_country.to_dict(orient='record'))

# %%
apps = list(cydb.topappies.find(projection={'_id':False}))

# %%
apps
# Out:
# [{'app_icon_css': 'gp',
#   'category': 'COMMUNICATION',
#   'category_id': 4,
#   'change': 0,
#   'company_name': 'WhatsApp',
#   'company_url': '/company/1000200000017524/',
#   'country_code': 'us',
#   'cy_category': 'Social',
#   'headerquarters': 'United States',
#   'iap': False,
#   'icon': 'https://static-s.aa-cdn.net/img/gp/20600000013820/mp86vbELnqLi2FzvhiKdPX31_oiTRLNyeK8x4IIrbF5eD1D5RdnVwjQP0hwMNR_JdA=s300_w80',
#   'id': 20600000013820,
#   'name': 'WhatsApp Messenger',
#   'package_name': 'com.whatsapp',
#   'rank': 1,
#   'rank_country': 'do',
#   'sort_metric': 'changeInRank',
#   'url': '/apps/google-play/app/com.whatsapp/details/'},
#  {'app_icon_css': 'gp',
#   'category': 'GAME_ARCADE',
#   'category_id': 1,
#   'change': 0,
#   'company_name': 'Mojang',
#   'company_url': '/company/1000200000016666/',
#   'country_code': 'se',
#   'cy_category': 'Games',
#   'headerquarters': 'Sweden',
#   'iap': True,
# ...

# %%
for i,app in enumerate(apps):
    if i%3 == 0:
        app['cy_category'] = 'Tools'
    elif i%3 == 1:
        app['cy_category'] = 'BBBB'
    else:
        app['cy_category'] = 'TOCE'

# %%
df = pd.DataFrame(apps)

# %%
 df.groupby('cy_category', as_index=False).count()['id']
# Out:
# 0    105
# 1    105
# 2    106
# Name: id, dtype: int64

# %%
cy_category_sort = df.groupby('cy_category', as_index=False, sort=False).count()[['cy_category', 'id']]

# %%
cy_category_sort = df.groupby('cy_category').count()['package_name'].sort_values(ascending=False)

# %%
mydict=dict(zip(cy_category_sort.index,range(1,len(cy_category_sort.index)+1)))

# %%
mydict
# Out:
# {'BBBB': 3, 'TOCE': 2, 'Tools': 1}

# %%
from collections import OrderedDict

# %%
cy_category_sort.sort_values(by='id', ascending=False).reset_index()['cy_category'].set_index('')
# Out:
# 0    Tools
# 1     BBBB
# 2     TOCE
# Name: cy_category, dtype: object

# %%
cy_category_sort.loc
# Out:
# Index(['Tools', 'TOCE', 'BBBB'], dtype='object', name='cy_category')

# %%
pipeline = [ {'$match':{'rank_country':'do'}}, {'$project':{'_id':0, 'p':'$package_name', 'id':'$rank', 'c':'$category_id'}}]

# %%
pipeline_not = [ {'$match':{'rank_country':{ '$ne': "do" }, 'package_name':{'$nin':topapp_for_do}}}, {'$project':{'_id':0, 'p':'$package_name', 'id':'$rank', 'c':'$category_id'}}, {'$sort':{'id':1}}, {'$limit':100}]

# %%
pipeline_cato = [ {'$match':{'rank_country':'do'}}, { '$group' : { '_id' : "$category_id", 'n':{'$first':'$cy_category'} } },
                                                     {'$project':{'_id':0, 'id':'$_id', 'n':'$n'}}]

# %%
b = list(cydb.topappies.aggregate(pipeline_cato))

# %%
n = list(cydb.topappies.aggregate(pipeline_not))

# %%
len(n)
# Out:
# 100

# %%
a = list(cydb.topappies.aggregate(pipeline))

# %%
topapp_for_do = [x['p'] for x in a]

# %%
pipeline = [ {'$match':{'rank_country':country}}, {'$project':{'_id':0, 'p':'$package_name', 'id':'$rank', 'c':'$category_id'}}]
    top_apps = list(cy.topappies.aggregate(pipeline))
    package_names = [x['p'] for x in top_apps]
    count = len(top_apps)

    pipeline_not = [ {'$match':{'rank_country':{ '$ne': country }, 'package_name':{'$nin':package_names}}}, {'$project':{'_id':0, 'p':'$package_name', 'id':'$rank', 'c':'$category_id'}}, {'$sort':{'id':1}}, {'$limit':4000}]

    for app in cy.topappies.aggregate(pipeline_not):
        app['id'] = count
        top_apps.append(app)
        count = count + 1
